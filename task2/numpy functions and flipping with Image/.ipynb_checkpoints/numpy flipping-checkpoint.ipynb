# %%
import numpy as np
import PIL.Image as im
import cv2
import matplotlib.pyplot as plt

# %%
img = im.open('./download.jfif')

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x16ECD3B5550>

# %%
img  = np.array(img)

# %%
def flip_bottom(img):
    f = np.flip(img,(0))
#     alt. method

#     f = img[::-1,::]
    img = im.fromarray(f)
    plt.imshow(img)

flip_farward(img)

# %%
def flip_backward_farward(img):
    f = img[::-1,::-1]
    plt.imshow(f)
flip_backward_farward(img)

# %%
def flip_left_right(img):
    f = np.fliplr(img)
#     alt. method
    f = img[::,::-1]
    plt.imshow(f)
flip_left_right(img)

# %%
# # img.traspose()
# img = im.fromarray(img)
# # cv2.imshow('cv2.imshow()img',img)
# # cv2.waitKey(0)
img.show()

# %%
# a = np.random.randint(0,,(500,500,3),dtype='uint')
a = np.zeros((500,500,3))
a[::100]=255

# %%
cv2.imshow('cv2.imshow()img',a)
cv2.waitKey(0)
